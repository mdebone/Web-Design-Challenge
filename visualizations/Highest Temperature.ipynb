# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
x = np.array([70,71, 72, 73, 74]) 
y = np.array([79.96, 48.2, 44.6, 82.39, 42.8])

# kaitangata, goulburn, lata, chokurdakh])
    
plt.plot(x, y)

plt.title("Highest Temp by City")
plt.xlabel("City")
plt.ylabel("Temperature")

plt.show()
