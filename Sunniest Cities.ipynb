# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
x = np.array([0,1, 2, 3, 40]) 
y = np.array([0, 100, 20, 76, 0])

# kaitangata, goulburn, lata, chokurdakh])
    
plt.plot(x, y)

plt.xlabel("City")
plt.ylabel("Lack of Clouds")

plt.show()
