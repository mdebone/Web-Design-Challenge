# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
x = np.array([100,101, 102, 103, 104]) 
y = np.array([3.36, 11.41, 4.63, 4.74, 5.64])

# kaitangata, goulburn, lata, chokurdakh])
    
plt.plot(x, y)

plt.title("Highest Wind by City")
plt.xlabel("City")
plt.ylabel("Recorded Max Wind")

plt.show()
